# %%
import yfinance as yf
from yfinance import EquityQuery

def extract_stock_list():
    # Define the custom query
    custom_query = EquityQuery('and', [
        # EquityQuery('gte', ['intradaymarketcap', 1000000000]),  # Market cap >= $1B
        EquityQuery('eq', ['region', 'us']),
        EquityQuery('gt', ['eodprice', 460]),               # Price > $10
        EquityQuery('lt', ['eodprice', 470]),
    ])

    # Run the screen, sorting by market cap descending
    response = yf.screen(custom_query, size=250, sortField='percentchange', sortAsc=False)
    
    # display(response)

    # Extract relevant fields from the response
    quotes = response['quotes']
    results = [
        {
            'ticker': stock['symbol'],
            'typeDisp': stock['typeDisp'],
            'volume': stock['regularMarketVolume'],
        }
        for stock in quotes
    ]

    # Print the results
    for result in results:
        print(f"Ticker: {result['ticker']}, typeDisp: ${result['typeDisp']}")

    # Extract tickers as a list
    tickers = [stock['symbol'] for stock in response['quotes']]

    # Print the list for verification
    print("Ticker list for yf.download:", tickers)

extract_stock_list()
# Out:
# Ticker: PONT, typeDisp: $Equity
# Ticker: WRLC, typeDisp: $Equity
# Ticker list for yf.download: ['PONT', 'WRLC']

# %%
from yfinance import FundQuery  # Hypothetical module - replace with actual import

def extract_fund_list():
    # Define the custom query
    custom_query = FundQuery('and', [
        FundQuery('eq', ['categoryname', 'Large Growth']),
        FundQuery('is-in', ['performanceratingoverall', 4, 5]),
        FundQuery('lt', ['initialinvestment', 100001]),
        FundQuery('lt', ['annualreturnnavy1categoryrank', 50]),
        FundQuery('eq', ['exchange', 'NAS'])
    ])

    # Run the screen, sorting by market cap descending
    response = yf.screen(custom_query, size=5, sortAsc=False)
    
    display(response)

    # Extract relevant fields from the response
    quotes = response['quotes']
    results = [
        {
            'ticker': stock['symbol'],
            'shortName': stock['shortName'],
            # 'volume': stock['regularMarketVolume'],
        }
        for stock in quotes
    ]

    # Print the results
    for result in results:
        print(f"Ticker: {result['ticker']}, Price: ${result['shortName']}")

    # Extract tickers as a list
    tickers = [stock['symbol'] for stock in response['quotes']]

    # Print the list for verification
    print("Ticker list for yf.download:", tickers)

extract_stock_list()
# Out:
# {'start': 0,
#  'count': 5,
#  'total': 190,
#  'quotes': [{'language': 'en-US',
#    'region': 'US',
#    'quoteType': 'MUTUALFUND',
#    'typeDisp': 'Fund',
#    'quoteSourceName': 'Delayed Quote',
#    'triggerable': False,
#    'customPriceAlertConfidence': 'NONE',
#    'hasPrePostMarketData': False,
#    'firstTradeDateMilliseconds': 1285162200000,
#    'priceHint': 2,
#    'currency': 'USD',
#    'regularMarketChange': -18.96,
#    'regularMarketTime': 1743206634,
#    'regularMarketPrice': 713.53,
#    'regularMarketPreviousClose': 732.49005,
#    'market': 'us_market',
#    'messageBoardId': 'finmb_113666141',
#    'fullExchangeName': 'Nasdaq',
#    'longName': 'Vanguard Russell 1000 Growth Index I',
#    'averageDailyVolume3Month': 0,
#    'averageDailyVolume10Day': 0,
#    'corporateActions': [],
#    'fiftyTwoWeekLowChange': 87.57001,
#    'fiftyTwoWeekLowChangePercent': 0.13989712,
#    'fiftyTwoWeekRange': '625.96 - 829.03',
#    'fiftyTwoWeekHighChange': -115.5,
#    'fiftyTwoWeekHighChangePercent': -0.13931943,
#    'fiftyTwoWeekChangePercent': 7.03218,
#    'trailingPE': 31.149761,
#    'dividendRate': 4.4724,
#    'ytdReturn': -1.69302,
#    'trailingThreeMonthReturns': -0.83403,
#    'netAssets': 33707223000.0,
#    'marketState': 'CLOSED',
#    'epsTrailingTwelveMonths': 22.906437,
#    'fiftyDayAverage': 779.6942,
#    'fiftyDayAverageChange': -66.164185,
#    'fiftyDayAverageChangePercent': -0.08485915,
#    'twoHundredDayAverage': 756.41675,
#    'twoHundredDayAverageChange': -42.88672,
#    'twoHundredDayAverageChangePercent': -0.05669721,
#    'sourceInterval': 15,
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'gmtOffSetMilliseconds': -14400000,
#    'esgPopulated': False,
#    'tradeable': False,
#    'cryptoTradeable': False,
#    'exchange': 'NAS',
#    'fiftyTwoWeekHigh': 829.03,
#    'fiftyTwoWeekLow': 625.96,
#    'dividendYield': 0.57,
#    'shortName': 'Vanguard Russell 1000 Growth In',
#    'netExpenseRatio': 0.06,
#    'regularMarketChangePercent': -2.588431,
#    'symbol': 'VRGWX'},
#   {'language': 'en-US',
#    'region': 'US',
#    'quoteType': 'MUTUALFUND',
#    'typeDisp': 'Fund',
#    'quoteSourceName': 'Delayed Quote',
#    'triggerable': False,
#    'customPriceAlertConfidence': 'NONE',
#    'hasPrePostMarketData': False,
#    'firstTradeDateMilliseconds': 1198765800000,
#    'priceHint': 2,
#    'currency': 'USD',
#    'regularMarketChange': -16.7,
#    'regularMarketTime': 1743206634,
#    'regularMarketPrice': 612.66,
#    'regularMarketPreviousClose': 629.36,
#    'market': 'us_market',
#    'messageBoardId': 'finmb_39636485',
#    'fullExchangeName': 'Nasdaq',
#    'longName': 'Vanguard Mega Cap Growth Index Instl',
#    'averageDailyVolume3Month': 0,
#    'averageDailyVolume10Day': 0,
#    'corporateActions': [],
#    'fiftyTwoWeekLowChange': 80.31,
#    'fiftyTwoWeekLowChangePercent': 0.1508594,
#    'fiftyTwoWeekRange': '532.35 - 710.78',
#    'fiftyTwoWeekHighChange': -98.120056,
#    'fiftyTwoWeekHighChangePercent': -0.1380456,
#    'fiftyTwoWeekChangePercent': 7.5615764,
#    'trailingAnnualDividendRate': 0.0,
#    'trailingPE': 33.861324,
#    'dividendRate': 2.9972,
#    'trailingAnnualDividendYield': 0.0,
#    'ytdReturn': -1.36671,
#    'trailingThreeMonthReturns': -0.22058,
#    'netAssets': 25008891900.0,
#    'marketState': 'CLOSED',
#    'epsTrailingTwelveMonths': 18.093208,
#    'fiftyDayAverage': 668.9918,
#    'fiftyDayAverageChange': -56.33185,
#    'fiftyDayAverageChangePercent': -0.08420409,
#    'twoHundredDayAverage': 650.5395,
#    'twoHundredDayAverageChange': -37.879517,
#    'twoHundredDayAverageChangePercent': -0.058227852,
#    'sourceInterval': 15,
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'gmtOffSetMilliseconds': -14400000,
#    'esgPopulated': False,
#    'tradeable': False,
#    'cryptoTradeable': False,
#    'exchange': 'NAS',
#    'fiftyTwoWeekHigh': 710.78,
#    'fiftyTwoWeekLow': 532.35,
#    'dividendYield': 0.45,
#    'shortName': 'Vanguard Mega Cap 300 Growth In',
#    'netExpenseRatio': 0.06,
#    'regularMarketChangePercent': -2.6534896,
#    'symbol': 'VMGAX'},
#   {'language': 'en-US',
#    'region': 'US',
#    'quoteType': 'MUTUALFUND',
#    'typeDisp': 'Fund',
#    'quoteSourceName': 'Delayed Quote',
#    'triggerable': False,
#    'customPriceAlertConfidence': 'NONE',
#    'hasPrePostMarketData': False,
#    'firstTradeDateMilliseconds': 720455400000,
#    'priceHint': 2,
#    'currency': 'USD',
#    'regularMarketChange': -5.18,
#    'regularMarketTime': 1743206634,
#    'regularMarketPrice': 190.77,
#    'regularMarketPreviousClose': 195.95,
#    'market': 'us_market',
#    'messageBoardId': 'finmb_22939698',
#    'fullExchangeName': 'Nasdaq',
#    'longName': 'Vanguard Growth Index Investor',
#    'financialCurrency': 'USD',
#    'averageDailyVolume3Month': 0,
#    'averageDailyVolume10Day': 0,
#    'corporateActions': [],
#    'fiftyTwoWeekLowChange': 24.75,
#    'fiftyTwoWeekLowChangePercent': 0.14907841,
#    'fiftyTwoWeekRange': '166.02 - 220.35',
#    'fiftyTwoWeekHighChange': -29.580002,
#    'fiftyTwoWeekHighChangePercent': -0.13424098,
#    'fiftyTwoWeekChangePercent': 7.603359,
#    'trailingAnnualDividendRate': 1.54,
#    'trailingPE': 33.14335,
#    'dividendRate': 0.7402,
#    'trailingAnnualDividendYield': 0.007859148,
#    'ytdReturn': -1.15481,
#    'trailingThreeMonthReturns': -0.71052,
#    'netAssets': 282600210000.0,
#    'marketState': 'CLOSED',
#    'epsTrailingTwelveMonths': 5.755906,
#    'sharesOutstanding': 822456000,
#    'bookValue': 215.749,
#    'fiftyDayAverage': 207.9528,
#    'fiftyDayAverageChange': -17.1828,
#    'fiftyDayAverageChangePercent': -0.08262836,
#    'twoHundredDayAverage': 201.6782,
#    'twoHundredDayAverageChange': -10.908203,
#    'twoHundredDayAverageChangePercent': -0.05408717,
#    'marketCap': 156899934208,
#    'priceToBook': 0.884222,
#    'sourceInterval': 15,
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'gmtOffSetMilliseconds': -14400000,
#    'esgPopulated': False,
#    'tradeable': False,
#    'cryptoTradeable': False,
#    'exchange': 'NAS',
#    'fiftyTwoWeekHigh': 220.35,
#    'fiftyTwoWeekLow': 166.02,
#    'dividendYield': 0.35,
#    'shortName': 'Vanguard Index Trust Growth Ind',
#    'netExpenseRatio': 0.17,
#    'regularMarketChangePercent': -2.6435313,
#    'symbol': 'VIGRX'},
#   {'language': 'en-US',
#    'region': 'US',
#    'quoteType': 'MUTUALFUND',
#    'typeDisp': 'Fund',
#    'quoteSourceName': 'Delayed Quote',
#    'triggerable': False,
#    'customPriceAlertConfidence': 'NONE',
#    'hasPrePostMarketData': False,
#    'firstTradeDateMilliseconds': 895152600000,
#    'priceHint': 2,
#    'currency': 'USD',
#    'regularMarketChange': -5.18,
#    'regularMarketTime': 1743206634,
#    'regularMarketPrice': 190.7,
#    'regularMarketPreviousClose': 195.87999,
#    'market': 'us_market',
#    'messageBoardId': 'finmb_22939698',
#    'fullExchangeName': 'Nasdaq',
#    'longName': 'Vanguard Growth Index Institutional',
#    'financialCurrency': 'USD',
#    'averageDailyVolume3Month': 0,
#    'averageDailyVolume10Day': 0,
#    'corporateActions': [],
#    'fiftyTwoWeekLowChange': 24.720001,
#    'fiftyTwoWeekLowChangePercent': 0.14893362,
#    'fiftyTwoWeekRange': '165.98 - 220.34',
#    'fiftyTwoWeekHighChange': -29.64,
#    'fiftyTwoWeekHighChangePercent': -0.13451938,
#    'fiftyTwoWeekChangePercent': 7.6002955,
#    'trailingAnnualDividendRate': 1.54,
#    'trailingPE': 33.132774,
#    'dividendRate': 0.9844,
#    'trailingAnnualDividendYield': 0.007861957,
#    'ytdReturn': -1.13147,
#    'trailingThreeMonthReturns': -0.67678,
#    'netAssets': 282600210000.0,
#    'marketState': 'CLOSED',
#    'epsTrailingTwelveMonths': 5.7556305,
#    'sharesOutstanding': 822456000,
#    'bookValue': 215.749,
#    'fiftyDayAverage': 207.9292,
#    'fiftyDayAverageChange': -17.229202,
#    'fiftyDayAverageChangePercent': -0.08286091,
#    'twoHundredDayAverage': 201.66225,
#    'twoHundredDayAverageChange': -10.96225,
#    'twoHundredDayAverageChangePercent': -0.054359455,
#    'marketCap': 156842360832,
#    'priceToBook': 0.8838975,
#    'sourceInterval': 15,
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'gmtOffSetMilliseconds': -14400000,
#    'esgPopulated': False,
#    'tradeable': False,
#    'cryptoTradeable': False,
#    'exchange': 'NAS',
#    'fiftyTwoWeekHigh': 220.34,
#    'fiftyTwoWeekLow': 165.98,
#    'dividendYield': 0.47,
#    'shortName': 'Vanguard Index Trust - Growth I',
#    'netExpenseRatio': 0.04,
#    'regularMarketChangePercent': -2.6444764,
#    'symbol': 'VIGIX'},
#   {'language': 'en-US',
#    'region': 'US',
#    'quoteType': 'MUTUALFUND',
#    'typeDisp': 'Fund',
#    'quoteSourceName': 'Delayed Quote',
#    'triggerable': False,
#    'customPriceAlertConfidence': 'NONE',
#    'hasPrePostMarketData': False,
#    'firstTradeDateMilliseconds': 974125800000,
#    'priceHint': 2,
#    'currency': 'USD',
#    'regularMarketChange': -5.18,
#    'regularMarketTime': 1743206634,
#    'regularMarketPrice': 190.69,
#    'regularMarketPreviousClose': 195.87,
#    'market': 'us_market',
#    'messageBoardId': 'finmb_22939698',
#    'fullExchangeName': 'Nasdaq',
#    'longName': 'Vanguard Growth Index Admiral',
#    'financialCurrency': 'USD',
#    'averageDailyVolume3Month': 0,
#    'averageDailyVolume10Day': 0,
#    'corporateActions': [],
#    'fiftyTwoWeekLowChange': 24.720001,
#    'fiftyTwoWeekLowChangePercent': 0.14894259,
#    'fiftyTwoWeekRange': '165.97 - 220.32',
#    'fiftyTwoWeekHighChange': -29.630005,
#    'fiftyTwoWeekHighChangePercent': -0.13448621,
#    'fiftyTwoWeekChangePercent': 7.6007247,
#    'trailingAnnualDividendRate': 1.54,
#    'trailingPE': 33.13421,
#    'dividendRate': 0.9657,
#    'trailingAnnualDividendYield': 0.007862357,
#    'ytdReturn': -1.13626,
#    'trailingThreeMonthReturns': -0.67909,
#    'netAssets': 282600210000.0,
#    'marketState': 'CLOSED',
#    'epsTrailingTwelveMonths': 5.7550793,
#    'sharesOutstanding': 822456000,
#    'bookValue': 215.749,
#    'fiftyDayAverage': 207.915,
#    'fiftyDayAverageChange': -17.22499,
#    'fiftyDayAverageChangePercent': -0.08284631,
#    'twoHundredDayAverage': 201.63216,
#    'twoHundredDayAverageChange': -10.942154,
#    'twoHundredDayAverageChangePercent': -0.054267902,
#    'marketCap': 156834136064,
#    'priceToBook': 0.8838512,
#    'sourceInterval': 15,
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'gmtOffSetMilliseconds': -14400000,
#    'esgPopulated': False,
#    'tradeable': False,
#    'cryptoTradeable': False,
#    'exchange': 'NAS',
#    'fiftyTwoWeekHigh': 220.32,
#    'fiftyTwoWeekLow': 165.97,
#    'dividendYield': 0.46,
#    'shortName': 'Vanguard Growth Index Fd Admira',
#    'netExpenseRatio': 0.05,
#    'regularMarketChangePercent': -2.6446111,
#    'symbol': 'VIGAX'}],
#  'useRecords': False}
# Ticker: VRGWX, Price: $Vanguard Russell 1000 Growth In
# Ticker: VMGAX, Price: $Vanguard Mega Cap 300 Growth In
# Ticker: VIGRX, Price: $Vanguard Index Trust Growth Ind
# Ticker: VIGIX, Price: $Vanguard Index Trust - Growth I
# Ticker: VIGAX, Price: $Vanguard Growth Index Fd Admira
# Ticker list for yf.download: ['VRGWX', 'VMGAX', 'VIGRX', 'VIGIX', 'VIGAX']
